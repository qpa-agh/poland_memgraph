# %%
import geopandas as gpd
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
from shapely import wkt

# %%
#  cities communes powiats voivodships
df = pd.read_csv('../data/ads24-countries.csv', low_memory=False)
df
# Out:
#       id         name                                                wkt
# 0  14296    Slovensko  LINESTRING(18.819233800000003 49.5162949000000...
# 1  49715       Polska  LINESTRING(14.078291700000001 54.4411306,14.06...
# 2  50046      Danmark  LINESTRING(14.344398900000002 55.1476253,14.34...
# 3  51477  Deutschland  LINESTRING(14.078291700000001 54.4411306,14.06...
# 4  51684        Česko  LINESTRING(14.8055929 50.8397881,14.8056452 50...
# 5  59065     Беларусь  MULTILINESTRING((23.6014449 53.927672900000005...
# 6  60189       Россия  LINESTRING(20.655716700000003 55.3842167,20.63...
# 7  60199      Україна  LINESTRING(23.643509700000003 51.5584108000000...
# 8  72596      Lietuva  MULTILINESTRING((22.766023200000003 54.3871248...

# %%
df['geometry'] = df['wkt'].apply(wkt.loads)
gdf = gpd.GeoDataFrame(df, crs="EPSG:4326", geometry='geometry')
gdf['lat'] = gdf.centroid.x
gdf['long'] = gdf.centroid.y

gdf.to_crs(epsg=2180, inplace=True)
gdf = pd.concat([gdf, gdf.bounds], axis=1)
gdf['wkt'] = gdf['geometry'].apply(wkt.dumps)
gdf = gdf.drop(['geometry'], axis=1)
gdf
# Out:
# /tmp/ipykernel_211108/20041386.py:3: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf['lat'] = gdf.centroid.x
# /tmp/ipykernel_211108/20041386.py:4: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf['long'] = gdf.centroid.y
#       id         name                                                wkt  \
# 0  14296    Slovensko  LINESTRING (486919.4336072048172355 183221.994...
# 1  49715       Polska  LINESTRING (181027.6568473152583465 741949.996...
# 2  50046      Danmark  LINESTRING (203484.8222099005943164 819280.038...
# 3  51477  Deutschland  LINESTRING (181027.6568473152583465 741949.996...
# 4  51684        Česko  LINESTRING (204809.6672761520603672 338703.370...
# 5  59065     Беларусь  MULTILINESTRING ((801954.9164775998797268 6834...
# 6  60189       Россия  LINESTRING (604862.6301148447673768 836953.103...
# 7  60199      Україна  LINESTRING (821729.9742698667105287 420432.262...
# 8  72596      Lietuva  MULTILINESTRING ((744434.9921001596376300 7313...
#
#          lat       long           minx           miny           maxx  \
# 0  20.565840  49.362347  486919.433607  139220.158128  760257.712416
# 1  19.287673  51.765622  171677.546261  133223.783877  861895.747011
# 2  14.984529  55.151424  202354.962568  775923.571356  281392.339268
# 3  14.549432  52.495324  171677.546261  338703.370397  224026.863917
# 4  16.880529  50.353430  204809.667276  183065.000635  489822.423411
# 5  23.620281  52.609237  784882.471013  413934.632182  833418.088663
# 6  20.732571  54.597609  526100.467147  719879.526227  746262.907821
# 7  23.450844  50.318409  759322.667052  133223.783877  861895.747011
# 8  23.279678  54.186504  744434.992100  683199.907348  806449.458929
#
#             maxy
# 0  194144.016559
# 1  797228.500785
# 2  858977.812456
# 3  741949.996798
# 4  358236.998716
# 5  686331.569963
# 6  836953.103713
# 7  420432.262992
# 8  734224.993752
